# %%
#Import dependencies 
import pandas as pd
import numpy as np
from citipy import citipy
from config import weather_api_key
import requests 
import time
from datetime import datetime

# %%
#Create a new set of 2,000 random latitudes and longitudes
lats = np.random.uniform(low= -90.000, high= 90.000,size=2000)
lngs = np.random.uniform(low= -180.000, high= 180.000, size=2000)
lat_longs = zip(lats,lngs)
lat_longs

# %%
#Add the latitudes and longitudes to a list
coords = list(lat_longs)

# %%
#create the nearest cities
cities = []
for coord in coords:
    city = citipy.nearest_city(coord[0],coord[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 746

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

#Start Logging

print('Retrieving Cities')
print('...please wait ....')

#Create counters
record_count = 1
set_count = 1

#loop through all the cities 
for i, city in enumerate(cities):
    #Group in sets of 50 for logggin
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
   
    #create endpoint for each city
    city_url = url + "&q=" + city.replace (" ", "+")
    
    #log the url, record, and set numbers and the city
    print(f"Processing Record{record_count} of Set {set_count} | {city}")
    
    #add 1 to the record count
    record_count += 1

#Run the API request 
    try:
        #parse JSON and retrieve data
        city_weather = requests.get(city_url).json()
        
        #parse data to retrieve
        city_lat = city_weather["coord"] ["lat"]
        city_lng = city_weather["coord"] ["lon"]
        city_max_temp = city_weather ["main"] ["temp_max"]
        city_humidity = city_weather ["main"] ["humidity"]
        city_clouds = city_weather ["clouds"] ["all"]
        city_wind = city_weather ["wind"] ["speed"]
        city_country = city_weather ["sys"] ["country"]
        city_description = city_weather ["weather"][0] ["description"]
        
        #covert date to the ISO standard
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%y-%m-%d %H:%M:%S')
        
        #Append the city information into city_data list defined above
        city_data.append({
            "City": city.title(),
            "Country" : city_country,
            "Lat" : city_lat,
            "Lng" : city_lng,
            "Max Temp" : city_max_temp,
            "Humidity" : city_humidity,
            "Cloudiness" : city_clouds, 
            "Wind Speed" : city_wind,
            "Description" : city_description,
          
            })
    except:
        print("City not found. Skipping....")
        pass
    
#Data loading is complete
print("--------------------")
print("Data Load Complete")
print("---Thanks for Waiting----")
# Out:
# Retrieving Cities
# ...please wait ....
# Processing Record1 of Set 1 | albany
# Processing Record2 of Set 1 | cape town
# Processing Record3 of Set 1 | susanville
# Processing Record4 of Set 1 | jamestown
# Processing Record5 of Set 1 | butaritari
# Processing Record6 of Set 1 | rikitea
# Processing Record7 of Set 1 | andenes
# Processing Record8 of Set 1 | saint-philippe
# Processing Record9 of Set 1 | hoa binh
# Processing Record10 of Set 1 | yellowknife
# Processing Record11 of Set 1 | garowe
# Processing Record12 of Set 1 | ribeira grande
# Processing Record13 of Set 1 | tasiilaq
# Processing Record14 of Set 1 | georgetown
# Processing Record15 of Set 1 | chokurdakh
# Processing Record16 of Set 1 | beringovskiy
# Processing Record17 of Set 1 | hofn
# Processing Record18 of Set 1 | bluff
# Processing Record19 of Set 1 | vaini
# Processing Record20 of Set 1 | saraipali
# Processing Record21 of Set 1 | praia da vitoria
# Processing Record22 of Set 1 | luderitz
# Processing Record23 of Set 1 | high prairie
# Processing Record24 of Set 1 | nicoya
# Processing Record25 of Set 1 | bredasdorp
# Processing Record26 of Set 1 | ushuaia
# Processing Record27 of Set 1 | fengzhen
# Processing Record28 of Set 1 | kapaa
# Processing Record29 of Set 1 | carnarvon
# Processing Record30 of Set 1 | pacific grove
# Processing Record31 of Set 1 | mataura
# Processing Record32 of Set 1 | alofi
# Processing Record33 of Set 1 | port alfred
# Processing Record34 of Set 1 | victoria
# Processing Record35 of Set 1 | prince rupert
# Processing Record36 of Set 1 | beloha
# Processing Record37 of Set 1 | punta arenas
# Processing Record38 of Set 1 | bambous virieux
# Processing Record39 of Set 1 | san luis de gaceno
# Processing Record40 of Set 1 | port elizabeth
# Processing Record41 of Set 1 | hermanus
# Processing Record42 of Set 1 | atuona
# Processing Record43 of Set 1 | dunmanway
# Processing Record44 of Set 1 | avarua
# Processing Record45 of Set 1 | qaanaaq
# Processing Record46 of Set 1 | verkhnevilyuysk
# Processing Record47 of Set 1 | correntina
# Processing Record48 of Set 1 | new norfolk
# Processing Record49 of Set 1 | sao joao do piaui
# Processing Record50 of Set 1 | srandakan
# Processing Record1 of Set 2 | cabedelo
# Processing Record2 of Set 2 | busselton
# Processing Record3 of Set 2 | hilo
# Processing Record4 of Set 2 | krasnoselkup
# Processing Record5 of Set 2 | olafsvik
# Processing Record6 of Set 2 | iqaluit
# Processing Record7 of Set 2 | lahij
# Processing Record8 of Set 2 | saldanha
# Processing Record9 of Set 2 | sabang
# Processing Record10 of Set 2 | tumannyy
# City not found. Skipping....
# Processing Record11 of Set 2 | hithadhoo
# Processing Record12 of Set 2 | rassvet
# Processing Record13 of Set 2 | santa eulalia del rio
# City not found. Skipping....
# Processing Record14 of Set 2 | hobart
# Processing Record15 of Set 2 | henties bay
# Processing Record16 of Set 2 | kirovskiy
# Processing Record17 of Set 2 | guerrero negro
# Processing Record18 of Set 2 | saryg-sep
# Processing Record19 of Set 2 | aasiaat
# Processing Record20 of Set 2 | pevek
# Processing Record21 of Set 2 | la estancia
# Processing Record22 of Set 2 | vuktyl
# Processing Record23 of Set 2 | provideniya
# Processing Record24 of Set 2 | nyurba
# Processing Record25 of Set 2 | illoqqortoormiut
# City not found. Skipping....
# Processing Record26 of Set 2 | kaitangata
# Processing Record27 of Set 2 | sheksna
# Processing Record28 of Set 2 | marcona
# City not found. Skipping....
# Processing Record29 of Set 2 | najran
# Processing Record30 of Set 2 | khatanga
# Processing Record31 of Set 2 | pisco
# Processing Record32 of Set 2 | vangaindrano
# Processing Record33 of Set 2 | umm lajj
# Processing Record34 of Set 2 | dauphin
# Processing Record35 of Set 2 | cherskiy
# Processing Record36 of Set 2 | vestmannaeyjar
# Processing Record37 of Set 2 | airai
# Processing Record38 of Set 2 | alice springs
# Processing Record39 of Set 2 | tineo
# Processing Record40 of Set 2 | mehamn
# Processing Record41 of Set 2 | bandarbeyla
# Processing Record42 of Set 2 | shelburne
# Processing Record43 of Set 2 | saint george
# Processing Record44 of Set 2 | berdigestyakh
# Processing Record45 of Set 2 | lodja
# Processing Record46 of Set 2 | chuy
# Processing Record47 of Set 2 | tezu
# Processing Record48 of Set 2 | atar
# Processing Record49 of Set 2 | karratha
# Processing Record50 of Set 2 | puro
# Processing Record1 of Set 3 | manzhouli
# Processing Record2 of Set 3 | los aquijes
# Processing Record3 of Set 3 | taolanaro
# City not found. Skipping....
# Processing Record4 of Set 3 | ostrovnoy
# Processing Record5 of Set 3 | salair
# Processing Record6 of Set 3 | pingdingshan
# Processing Record7 of Set 3 | castro
# Processing Record8 of Set 3 | maceio
# Processing Record9 of Set 3 | saint-augustin
# Processing Record10 of Set 3 | sampit
# Processing Record11 of Set 3 | arraial do cabo
# Processing Record12 of Set 3 | shimoda
# Processing Record13 of Set 3 | komsomolskiy
# Processing Record14 of Set 3 | jinchengjiang
# City not found. Skipping....
# Processing Record15 of Set 3 | nizhneyansk
# City not found. Skipping....
# Processing Record16 of Set 3 | milingimbi
# City not found. Skipping....
# Processing Record17 of Set 3 | lavrentiya
# Processing Record18 of Set 3 | manakara
# Processing Record19 of Set 3 | tidore
# City not found. Skipping....
# Processing Record20 of Set 3 | jumla
# Processing Record21 of Set 3 | krasnoyarskiy
# Processing Record22 of Set 3 | upernavik
# Processing Record23 of Set 3 | mar del plata
# Processing Record24 of Set 3 | soderhamn
# Processing Record25 of Set 3 | kodiak
# Processing Record26 of Set 3 | tabiauea
# City not found. Skipping....
# Processing Record27 of Set 3 | buta
# Processing Record28 of Set 3 | lasa
# Processing Record29 of Set 3 | suihua
# Processing Record30 of Set 3 | geraldton
# Processing Record31 of Set 3 | leninsk
# Processing Record32 of Set 3 | kawalu
# Processing Record33 of Set 3 | lebu
# Processing Record34 of Set 3 | cap malheureux
# Processing Record35 of Set 3 | zeya
# Processing Record36 of Set 3 | puerto ayora
# Processing Record37 of Set 3 | tuatapere
# Processing Record38 of Set 3 | ugoofaaru
# Processing Record39 of Set 3 | vysokogornyy
# Processing Record40 of Set 3 | mys shmidta
# City not found. Skipping....
# Processing Record41 of Set 3 | east london
# Processing Record42 of Set 3 | solnechnyy
# Processing Record43 of Set 3 | tiksi
# Processing Record44 of Set 3 | cooma
# Processing Record45 of Set 3 | morant bay
# Processing Record46 of Set 3 | salalah
# Processing Record47 of Set 3 | atagay
# Processing Record48 of Set 3 | mayo
# Processing Record49 of Set 3 | haldaur
# Processing Record50 of Set 3 | leningradskiy
# Processing Record1 of Set 4 | barrow
# Processing Record2 of Set 4 | brookings
# Processing Record3 of Set 4 | swan hill
# Processing Record4 of Set 4 | sao gabriel da cachoeira
# Processing Record5 of Set 4 | havre-saint-pierre
# Processing Record6 of Set 4 | ilulissat
# Processing Record7 of Set 4 | grenaa
# Processing Record8 of Set 4 | saint-georges
# Processing Record9 of Set 4 | fortuna
# Processing Record10 of Set 4 | udachnyy
# Processing Record11 of Set 4 | ancud
# Processing Record12 of Set 4 | presidencia roque saenz pena
# Processing Record13 of Set 4 | erenhot
# Processing Record14 of Set 4 | araouane
# Processing Record15 of Set 4 | klaksvik
# Processing Record16 of Set 4 | hermon
# Processing Record17 of Set 4 | mullaitivu
# City not found. Skipping....
# Processing Record18 of Set 4 | boa vista
# Processing Record19 of Set 4 | santa cruz de tenerife
# Processing Record20 of Set 4 | marawi
# Processing Record21 of Set 4 | dicabisagan
# Processing Record22 of Set 4 | chimoio
# Processing Record23 of Set 4 | ucluelet
# Processing Record24 of Set 4 | san quintin
# Processing Record25 of Set 4 | vila do maio
# Processing Record26 of Set 4 | vanimo
# Processing Record27 of Set 4 | bargal
# City not found. Skipping....
# Processing Record28 of Set 4 | taoudenni
# Processing Record29 of Set 4 | muros
# Processing Record30 of Set 4 | mariani
# Processing Record31 of Set 4 | harper
# Processing Record32 of Set 4 | faya
# Processing Record33 of Set 4 | grand gaube
# Processing Record34 of Set 4 | gambela
# Processing Record35 of Set 4 | corralillo
# Processing Record36 of Set 4 | noumea
# Processing Record37 of Set 4 | dikson
# Processing Record38 of Set 4 | gobabis
# Processing Record39 of Set 4 | san lawrenz
# Processing Record40 of Set 4 | sumbe
# Processing Record41 of Set 4 | bethel
# Processing Record42 of Set 4 | katsuura
# Processing Record43 of Set 4 | baykit
# Processing Record44 of Set 4 | kuche
# City not found. Skipping....
# Processing Record45 of Set 4 | ponta do sol
# Processing Record46 of Set 4 | dehloran
# Processing Record47 of Set 4 | palmer
# Processing Record48 of Set 4 | abha
# Processing Record49 of Set 4 | nanortalik
# Processing Record50 of Set 4 | leshukonskoye
# Processing Record1 of Set 5 | the pas
# Processing Record2 of Set 5 | vao
# Processing Record3 of Set 5 | te anau
# Processing Record4 of Set 5 | sentyabrskiy
# City not found. Skipping....
# Processing Record5 of Set 5 | chabahar
# Processing Record6 of Set 5 | ust-ilimsk
# Processing Record7 of Set 5 | byron bay
# Processing Record8 of Set 5 | bon accord
# Processing Record9 of Set 5 | westport
# Processing Record10 of Set 5 | uryupinsk
# Processing Record11 of Set 5 | tura
# Processing Record12 of Set 5 | cardiff
# Processing Record13 of Set 5 | chulman
# Processing Record14 of Set 5 | tsumeb
# Processing Record15 of Set 5 | half moon bay
# Processing Record16 of Set 5 | sao filipe
# Processing Record17 of Set 5 | amderma
# City not found. Skipping....
# Processing Record18 of Set 5 | rincon
# Processing Record19 of Set 5 | hovd
# Processing Record20 of Set 5 | biak
# Processing Record21 of Set 5 | asau
# Processing Record22 of Set 5 | aklavik
# Processing Record23 of Set 5 | los reyes
# Processing Record24 of Set 5 | meyungs
# City not found. Skipping....
# Processing Record25 of Set 5 | bengkulu
# Processing Record26 of Set 5 | bereda
# Processing Record27 of Set 5 | acapulco
# Processing Record28 of Set 5 | masterton
# Processing Record29 of Set 5 | vostok
# Processing Record30 of Set 5 | kutum
# Processing Record31 of Set 5 | lazarev
# Processing Record32 of Set 5 | champaign
# Processing Record33 of Set 5 | saint anthony
# Processing Record34 of Set 5 | churapcha
# Processing Record35 of Set 5 | mount gambier
# Processing Record36 of Set 5 | carballo
# Processing Record37 of Set 5 | havoysund
# Processing Record38 of Set 5 | griffith
# Processing Record39 of Set 5 | sembe
# Processing Record40 of Set 5 | yulara
# Processing Record41 of Set 5 | flinders
# Processing Record42 of Set 5 | attawapiskat
# City not found. Skipping....
# Processing Record43 of Set 5 | pangai
# Processing Record44 of Set 5 | quelimane
# Processing Record45 of Set 5 | belushya guba
# City not found. Skipping....
# Processing Record46 of Set 5 | faanui
# Processing Record47 of Set 5 | hasaki
# Processing Record48 of Set 5 | narsaq
# Processing Record49 of Set 5 | egvekinot
# Processing Record50 of Set 5 | codajas
# Processing Record1 of Set 6 | aquiraz
# Processing Record2 of Set 6 | khani
# Processing Record3 of Set 6 | sungai udang
# Processing Record4 of Set 6 | berlevag
# Processing Record5 of Set 6 | samalaeulu
# City not found. Skipping....
# Processing Record6 of Set 6 | chake chake
# Processing Record7 of Set 6 | padang
# Processing Record8 of Set 6 | diu
# Processing Record9 of Set 6 | dabakala
# Processing Record10 of Set 6 | shunyi
# Processing Record11 of Set 6 | tasbuget
# City not found. Skipping....
# Processing Record12 of Set 6 | topeka
# Processing Record13 of Set 6 | bathsheba
# Processing Record14 of Set 6 | halalo
# City not found. Skipping....
# Processing Record15 of Set 6 | kamenskoye
# City not found. Skipping....
# Processing Record16 of Set 6 | marshall
# Processing Record17 of Set 6 | sitka
# Processing Record18 of Set 6 | el dorado
# Processing Record19 of Set 6 | aksu
# Processing Record20 of Set 6 | kaeo
# Processing Record21 of Set 6 | dodge city
# Processing Record22 of Set 6 | luba
# Processing Record23 of Set 6 | cockburn town
# Processing Record24 of Set 6 | kolimvari
# City not found. Skipping....
# Processing Record25 of Set 6 | darabani
# Processing Record26 of Set 6 | chaman
# Processing Record27 of Set 6 | kungurtug
# Processing Record28 of Set 6 | haines junction
# Processing Record29 of Set 6 | thompson
# Processing Record30 of Set 6 | kommunisticheskiy
# Processing Record31 of Set 6 | abnub
# Processing Record32 of Set 6 | saint-pierre
# Processing Record33 of Set 6 | nizhniy tsasuchey
# Processing Record34 of Set 6 | kamenka
# Processing Record35 of Set 6 | husavik
# Processing Record36 of Set 6 | kenai
# Processing Record37 of Set 6 | saint-leu
# Processing Record38 of Set 6 | blackfoot
# Processing Record39 of Set 6 | mubende
# Processing Record40 of Set 6 | sioux lookout
# Processing Record41 of Set 6 | galeana
# Processing Record42 of Set 6 | shenkursk
# Processing Record43 of Set 6 | matay
# Processing Record44 of Set 6 | tatawin
# Processing Record45 of Set 6 | port lincoln
# Processing Record46 of Set 6 | souillac
# Processing Record47 of Set 6 | ondorhaan
# City not found. Skipping....
# Processing Record48 of Set 6 | baker city
# Processing Record49 of Set 6 | tsihombe
# City not found. Skipping....
# Processing Record50 of Set 6 | kalmar
# Processing Record1 of Set 7 | kruisfontein
# Processing Record2 of Set 7 | inhambane
# Processing Record3 of Set 7 | poso
# Processing Record4 of Set 7 | kokopo
# Processing Record5 of Set 7 | fort nelson
# Processing Record6 of Set 7 | orotukan
# Processing Record7 of Set 7 | saleaula
# City not found. Skipping....
# Processing Record8 of Set 7 | gimli
# Processing Record9 of Set 7 | jinchang
# Processing Record10 of Set 7 | duz
# City not found. Skipping....
# Processing Record11 of Set 7 | alexandria
# Processing Record12 of Set 7 | talaya
# Processing Record13 of Set 7 | kununurra
# Processing Record14 of Set 7 | honiara
# Processing Record15 of Set 7 | asyut
# Processing Record16 of Set 7 | muli
# Processing Record17 of Set 7 | barentsburg
# City not found. Skipping....
# Processing Record18 of Set 7 | tavda
# Processing Record19 of Set 7 | hervey bay
# Processing Record20 of Set 7 | vila
# Processing Record21 of Set 7 | nome
# Processing Record22 of Set 7 | torbay
# Processing Record23 of Set 7 | constitucion
# Processing Record24 of Set 7 | warqla
# City not found. Skipping....
# Processing Record25 of Set 7 | qasigiannguit
# Processing Record26 of Set 7 | port blair
# Processing Record27 of Set 7 | okha
# Processing Record28 of Set 7 | kalabo
# Processing Record29 of Set 7 | talnakh
# Processing Record30 of Set 7 | vardo
# Processing Record31 of Set 7 | namatanai
# Processing Record32 of Set 7 | takoradi
# Processing Record33 of Set 7 | clyde river
# Processing Record34 of Set 7 | novikovo
# Processing Record35 of Set 7 | azimur
# City not found. Skipping....
# Processing Record36 of Set 7 | barawe
# City not found. Skipping....
# Processing Record37 of Set 7 | bulawayo
# Processing Record38 of Set 7 | inverbervie
# Processing Record39 of Set 7 | zhigansk
# Processing Record40 of Set 7 | tuktoyaktuk
# Processing Record41 of Set 7 | coahuayana
# Processing Record42 of Set 7 | gat
# Processing Record43 of Set 7 | tubruq
# City not found. Skipping....
# Processing Record44 of Set 7 | tombouctou
# Processing Record45 of Set 7 | baturaja
# Processing Record46 of Set 7 | longyearbyen
# Processing Record47 of Set 7 | longyan
# Processing Record48 of Set 7 | jiwani
# Processing Record49 of Set 7 | cabo san lucas
# Processing Record50 of Set 7 | barguzin
# Processing Record1 of Set 8 | kassala
# Processing Record2 of Set 8 | vikevag
# Processing Record3 of Set 8 | gao
# Processing Record4 of Set 8 | labutta
# City not found. Skipping....
# Processing Record5 of Set 8 | kavieng
# Processing Record6 of Set 8 | rabo de peixe
# Processing Record7 of Set 8 | san patricio
# Processing Record8 of Set 8 | tazovskiy
# Processing Record9 of Set 8 | wanganui
# Processing Record10 of Set 8 | waiuku
# Processing Record11 of Set 8 | wagga wagga
# Processing Record12 of Set 8 | bilma
# Processing Record13 of Set 8 | lagoa
# Processing Record14 of Set 8 | naples
# Processing Record15 of Set 8 | naze
# Processing Record16 of Set 8 | aswan
# Processing Record17 of Set 8 | libreville
# Processing Record18 of Set 8 | hazorasp
# Processing Record19 of Set 8 | lujiang
# Processing Record20 of Set 8 | muhlacker
# Processing Record21 of Set 8 | dingle
# Processing Record22 of Set 8 | waipawa
# Processing Record23 of Set 8 | camacha
# Processing Record24 of Set 8 | salta
# Processing Record25 of Set 8 | nikolskoye
# Processing Record26 of Set 8 | yumen
# Processing Record27 of Set 8 | rocha
# Processing Record28 of Set 8 | mtwara
# Processing Record29 of Set 8 | carutapera
# Processing Record30 of Set 8 | sambava
# Processing Record31 of Set 8 | balykshi
# Processing Record32 of Set 8 | kodinsk
# Processing Record33 of Set 8 | pontianak
# Processing Record34 of Set 8 | severo-kurilsk
# Processing Record35 of Set 8 | shubarkuduk
# Processing Record36 of Set 8 | cidreira
# Processing Record37 of Set 8 | sur
# Processing Record38 of Set 8 | cholet
# Processing Record39 of Set 8 | saqqez
# Processing Record40 of Set 8 | macomb
# Processing Record41 of Set 8 | shache
# Processing Record42 of Set 8 | nara
# Processing Record43 of Set 8 | port hardy
# Processing Record44 of Set 8 | lompoc
# Processing Record45 of Set 8 | malanje
# Processing Record46 of Set 8 | state college
# Processing Record47 of Set 8 | gazanjyk
# Processing Record48 of Set 8 | pecos
# Processing Record49 of Set 8 | naliya
# Processing Record50 of Set 8 | namibe
# Processing Record1 of Set 9 | kupang
# Processing Record2 of Set 9 | coihaique
# Processing Record3 of Set 9 | sinnamary
# Processing Record4 of Set 9 | nikki
# Processing Record5 of Set 9 | yamada
# Processing Record6 of Set 9 | beidao
# Processing Record7 of Set 9 | grindavik
# Processing Record8 of Set 9 | codrington
# Processing Record9 of Set 9 | hami
# Processing Record10 of Set 9 | chiredzi
# Processing Record11 of Set 9 | portland
# Processing Record12 of Set 9 | avera
# Processing Record13 of Set 9 | jalgaon
# Processing Record14 of Set 9 | dwarka
# Processing Record15 of Set 9 | mikhaylovskoye
# Processing Record16 of Set 9 | safwah
# City not found. Skipping....
# Processing Record17 of Set 9 | calhoun
# Processing Record18 of Set 9 | mahibadhoo
# Processing Record19 of Set 9 | kirakira
# Processing Record20 of Set 9 | bakel
# Processing Record21 of Set 9 | ruatoria
# City not found. Skipping....
# Processing Record22 of Set 9 | rio grande
# Processing Record23 of Set 9 | bueu
# Processing Record24 of Set 9 | dzhusaly
# City not found. Skipping....
# Processing Record25 of Set 9 | necochea
# Processing Record26 of Set 9 | ozernovskiy
# Processing Record27 of Set 9 | nishihara
# Processing Record28 of Set 9 | vila franca do campo
# Processing Record29 of Set 9 | marsh harbour
# Processing Record30 of Set 9 | ouegoa
# Processing Record31 of Set 9 | ambon
# Processing Record32 of Set 9 | tongzi
# Processing Record33 of Set 9 | ahipara
# Processing Record34 of Set 9 | kavaratti
# Processing Record35 of Set 9 | vaitupu
# City not found. Skipping....
# Processing Record36 of Set 9 | colares
# Processing Record37 of Set 9 | bilibino
# Processing Record38 of Set 9 | la palma
# Processing Record39 of Set 9 | dabat
# Processing Record40 of Set 9 | palabuhanratu
# City not found. Skipping....
# Processing Record41 of Set 9 | vetlanda
# Processing Record42 of Set 9 | alappuzha
# Processing Record43 of Set 9 | jimenez
# Processing Record44 of Set 9 | kandalaksha
# Processing Record45 of Set 9 | vila velha
# Processing Record46 of Set 9 | wanning
# Processing Record47 of Set 9 | san andres
# Processing Record48 of Set 9 | ramsar
# Processing Record49 of Set 9 | ivanava
# Processing Record50 of Set 9 | slave lake
# Processing Record1 of Set 10 | usinsk
# Processing Record2 of Set 10 | umzimvubu
# City not found. Skipping....
# Processing Record3 of Set 10 | deputatskiy
# Processing Record4 of Set 10 | vestbygda
# City not found. Skipping....
# Processing Record5 of Set 10 | leh
# Processing Record6 of Set 10 | sanchor
# Processing Record7 of Set 10 | nortelandia
# Processing Record8 of Set 10 | kubuta
# Processing Record9 of Set 10 | bangkalan
# Processing Record10 of Set 10 | karauzyak
# City not found. Skipping....
# Processing Record11 of Set 10 | adrar
# Processing Record12 of Set 10 | brae
# Processing Record13 of Set 10 | ust-barguzin
# Processing Record14 of Set 10 | muhos
# Processing Record15 of Set 10 | talakan
# Processing Record16 of Set 10 | baghdad
# Processing Record17 of Set 10 | los llanos de aridane
# Processing Record18 of Set 10 | ahuimanu
# Processing Record19 of Set 10 | polunochnoye
# Processing Record20 of Set 10 | sept-iles
# Processing Record21 of Set 10 | palu
# Processing Record22 of Set 10 | kattivakkam
# Processing Record23 of Set 10 | saryozek
# Processing Record24 of Set 10 | assomada
# Processing Record25 of Set 10 | itamaraca
# Processing Record26 of Set 10 | saint-denis
# Processing Record27 of Set 10 | lamtah
# Processing Record28 of Set 10 | omsukchan
# Processing Record29 of Set 10 | probistip
# Processing Record30 of Set 10 | kozhva
# Processing Record31 of Set 10 | kahului
# Processing Record32 of Set 10 | kolda
# Processing Record33 of Set 10 | majene
# Processing Record34 of Set 10 | mantua
# Processing Record35 of Set 10 | isangel
# Processing Record36 of Set 10 | nogliki
# Processing Record37 of Set 10 | kandrian
# Processing Record38 of Set 10 | belmonte
# Processing Record39 of Set 10 | black river
# Processing Record40 of Set 10 | pandan
# Processing Record41 of Set 10 | kayerkan
# Processing Record42 of Set 10 | nouadhibou
# Processing Record43 of Set 10 | ngukurr
# City not found. Skipping....
# Processing Record44 of Set 10 | jinka
# Processing Record45 of Set 10 | hidrolandia
# Processing Record46 of Set 10 | kirillov
# Processing Record47 of Set 10 | chom bung
# City not found. Skipping....
# Processing Record48 of Set 10 | fokino
# Processing Record49 of Set 10 | esperance
# Processing Record50 of Set 10 | saskylakh
# Processing Record1 of Set 11 | tres arroyos
# Processing Record2 of Set 11 | mujiayingzi
# Processing Record3 of Set 11 | maumere
# Processing Record4 of Set 11 | grand river south east
# City not found. Skipping....
# Processing Record5 of Set 11 | jacareacanga
# Processing Record6 of Set 11 | homer
# Processing Record7 of Set 11 | pozo colorado
# Processing Record8 of Set 11 | quatre cocos
# Processing Record9 of Set 11 | shilovo
# Processing Record10 of Set 11 | guanhaes
# Processing Record11 of Set 11 | varkaus
# Processing Record12 of Set 11 | ambulu
# Processing Record13 of Set 11 | ampanihy
# Processing Record14 of Set 11 | katha
# City not found. Skipping....
# Processing Record15 of Set 11 | edd
# Processing Record16 of Set 11 | mbeya
# Processing Record17 of Set 11 | tarko-sale
# Processing Record18 of Set 11 | puerto concordia
# Processing Record19 of Set 11 | arman
# Processing Record20 of Set 11 | oistins
# Processing Record21 of Set 11 | pundaguitan
# Processing Record22 of Set 11 | benjamin constant
# Processing Record23 of Set 11 | kolokani
# Processing Record24 of Set 11 | utiroa
# City not found. Skipping....
# Processing Record25 of Set 11 | hamilton
# Processing Record26 of Set 11 | krasne
# Processing Record27 of Set 11 | searcy
# Processing Record28 of Set 11 | paita
# Processing Record29 of Set 11 | seryshevo
# Processing Record30 of Set 11 | gornopravdinsk
# Processing Record31 of Set 11 | yar-sale
# Processing Record32 of Set 11 | neka
# Processing Record33 of Set 11 | tumaco
# Processing Record34 of Set 11 | warri
# Processing Record35 of Set 11 | sola
# Processing Record36 of Set 11 | cassilandia
# Processing Record37 of Set 11 | turrialba
# Processing Record38 of Set 11 | tarnogskiy gorodok
# Processing Record39 of Set 11 | praia
# Processing Record40 of Set 11 | monmouth
# Processing Record41 of Set 11 | ukiah
# Processing Record42 of Set 11 | tessalit
# Processing Record43 of Set 11 | edinburg
# Processing Record44 of Set 11 | ilhabela
# Processing Record45 of Set 11 | bambanglipuro
# Processing Record46 of Set 11 | kosum phisai
# Processing Record47 of Set 11 | totskoye
# Processing Record48 of Set 11 | cayenne
# Processing Record49 of Set 11 | micheweni
# Processing Record50 of Set 11 | baruun-urt
# Processing Record1 of Set 12 | tilichiki
# Processing Record2 of Set 12 | port-gentil
# Processing Record3 of Set 12 | andra
# Processing Record4 of Set 12 | lake havasu city
# Processing Record5 of Set 12 | sao felix do xingu
# Processing Record6 of Set 12 | arnhem
# Processing Record7 of Set 12 | jalu
# Processing Record8 of Set 12 | iquitos
# Processing Record9 of Set 12 | talavera
# Processing Record10 of Set 12 | mitsamiouli
# Processing Record11 of Set 12 | naryan-mar
# Processing Record12 of Set 12 | akyab
# Processing Record13 of Set 12 | stoyba
# City not found. Skipping....
# Processing Record14 of Set 12 | mukdahan
# Processing Record15 of Set 12 | matara
# Processing Record16 of Set 12 | tortoli
# Processing Record17 of Set 12 | wuan
# Processing Record18 of Set 12 | nefteyugansk
# Processing Record19 of Set 12 | zyryanka
# Processing Record20 of Set 12 | novo cruzeiro
# Processing Record21 of Set 12 | forest grove
# Processing Record22 of Set 12 | zavodoukovsk
# Processing Record23 of Set 12 | labuan
# Processing Record24 of Set 12 | sisimiut
# Processing Record25 of Set 12 | kukushtan
# Processing Record26 of Set 12 | sobolevo
# Processing Record27 of Set 12 | tokonou
# Processing Record28 of Set 12 | amudat
# Processing Record29 of Set 12 | okhotsk
# Processing Record30 of Set 12 | nanning
# Processing Record31 of Set 12 | awbari
# Processing Record32 of Set 12 | sangar
# Processing Record33 of Set 12 | tokur
# Processing Record34 of Set 12 | rio gallegos
# Processing Record35 of Set 12 | ercis
# Processing Record36 of Set 12 | haibowan
# City not found. Skipping....
# Processing Record37 of Set 12 | coos bay
# Processing Record38 of Set 12 | truckee
# Processing Record39 of Set 12 | canutama
# Processing Record40 of Set 12 | basco
# Processing Record41 of Set 12 | sukhinichi
# Processing Record42 of Set 12 | mount isa
# Processing Record43 of Set 12 | qinzhou
# Processing Record44 of Set 12 | arlit
# Processing Record45 of Set 12 | irtyshskiy
# Processing Record46 of Set 12 | zhangye
# Processing Record47 of Set 12 | alta floresta
# Processing Record48 of Set 12 | mount pleasant
# Processing Record49 of Set 12 | wenzhou
# Processing Record50 of Set 12 | maniitsoq
# Processing Record1 of Set 13 | laguna
# Processing Record2 of Set 13 | bahia blanca
# Processing Record3 of Set 13 | zavetnoye
# Processing Record4 of Set 13 | jiddah
# City not found. Skipping....
# Processing Record5 of Set 13 | pilot butte
# Processing Record6 of Set 13 | viesca
# Processing Record7 of Set 13 | winnemucca
# Processing Record8 of Set 13 | erdenet
# Processing Record9 of Set 13 | sawakin
# Processing Record10 of Set 13 | grande riviere du nord
# Processing Record11 of Set 13 | nouakchott
# Processing Record12 of Set 13 | adilabad
# Processing Record13 of Set 13 | sorvag
# City not found. Skipping....
# Processing Record14 of Set 13 | murray bridge
# Processing Record15 of Set 13 | colquechaca
# Processing Record16 of Set 13 | rumoi
# Processing Record17 of Set 13 | kampong thum
# Processing Record18 of Set 13 | katsiveli
# City not found. Skipping....
# Processing Record19 of Set 13 | bull savanna
# Processing Record20 of Set 13 | tomari
# Processing Record21 of Set 13 | salmo
# Processing Record22 of Set 13 | meulaboh
# Processing Record23 of Set 13 | esso
# Processing Record24 of Set 13 | kumba
# Processing Record25 of Set 13 | shkoder
# Processing Record26 of Set 13 | bestobe
# Processing Record27 of Set 13 | alice town
# Processing Record28 of Set 13 | lorengau
# Processing Record29 of Set 13 | touros
# Processing Record30 of Set 13 | fortuna foothills
# Processing Record31 of Set 13 | ogaminana
# Processing Record32 of Set 13 | mahebourg
# Processing Record33 of Set 13 | belaya gora
# Processing Record34 of Set 13 | honningsvag
# Processing Record35 of Set 13 | port-de-paix
# City not found. Skipping....
# Processing Record36 of Set 13 | zinder
# Processing Record37 of Set 13 | semey
# Processing Record38 of Set 13 | kudahuvadhoo
# Processing Record39 of Set 13 | rorvik
# Processing Record40 of Set 13 | romanovka
# Processing Record41 of Set 13 | hobyo
# Processing Record42 of Set 13 | san jose
# Processing Record43 of Set 13 | farah
# Processing Record44 of Set 13 | monrovia
# Processing Record45 of Set 13 | kousseri
# Processing Record46 of Set 13 | privolzhye
# Processing Record47 of Set 13 | bolungarvik
# City not found. Skipping....
# Processing Record48 of Set 13 | bonavista
# Processing Record49 of Set 13 | nosy varika
# Processing Record50 of Set 13 | ambilobe
# Processing Record1 of Set 14 | vallenar
# Processing Record2 of Set 14 | kovdor
# Processing Record3 of Set 14 | thio
# Processing Record4 of Set 14 | broken hill
# Processing Record5 of Set 14 | antofagasta
# Processing Record6 of Set 14 | san rafael
# Processing Record7 of Set 14 | jasper
# Processing Record8 of Set 14 | midyat
# Processing Record9 of Set 14 | marsala
# Processing Record10 of Set 14 | aranos
# Processing Record11 of Set 14 | muzquiz
# City not found. Skipping....
# Processing Record12 of Set 14 | koumac
# Processing Record13 of Set 14 | acarau
# Processing Record14 of Set 14 | dandong
# Processing Record15 of Set 14 | coquimbo
# Processing Record16 of Set 14 | lumphat
# Processing Record17 of Set 14 | tigil
# Processing Record18 of Set 14 | san felipe
# Processing Record19 of Set 14 | grand-santi
# Processing Record20 of Set 14 | kamyaran
# Processing Record21 of Set 14 | potgietersrus
# City not found. Skipping....
# Processing Record22 of Set 14 | somerset west
# Processing Record23 of Set 14 | iquique
# Processing Record24 of Set 14 | shpykiv
# City not found. Skipping....
# Processing Record25 of Set 14 | bayir
# Processing Record26 of Set 14 | grimsby
# Processing Record27 of Set 14 | fairbanks
# Processing Record28 of Set 14 | kargasok
# Processing Record29 of Set 14 | angol
# Processing Record30 of Set 14 | monte gordo
# Processing Record31 of Set 14 | kysyl-syr
# Processing Record32 of Set 14 | limbang
# Processing Record33 of Set 14 | zhanatas
# City not found. Skipping....
# Processing Record34 of Set 14 | mirnyy
# Processing Record35 of Set 14 | massaranduba
# Processing Record36 of Set 14 | sirjan
# Processing Record37 of Set 14 | todos santos
# Processing Record38 of Set 14 | camabatela
# Processing Record39 of Set 14 | zhezkazgan
# Processing Record40 of Set 14 | bondo
# Processing Record41 of Set 14 | coralville
# Processing Record42 of Set 14 | shirokiy
# Processing Record43 of Set 14 | synya
# Processing Record44 of Set 14 | charters towers
# Processing Record45 of Set 14 | lata
# Processing Record46 of Set 14 | kasulu
# Processing Record47 of Set 14 | toliary
# City not found. Skipping....
# Processing Record48 of Set 14 | shellbrook
# Processing Record49 of Set 14 | pyaozerskiy
# Processing Record50 of Set 14 | sao teotonio
# Processing Record1 of Set 15 | evensk
# Processing Record2 of Set 15 | broome
# Processing Record3 of Set 15 | naftah
# City not found. Skipping....
# Processing Record4 of Set 15 | voznesenskoye
# Processing Record5 of Set 15 | ketchikan
# Processing Record6 of Set 15 | muzhi
# Processing Record7 of Set 15 | paamiut
# Processing Record8 of Set 15 | hollins
# Processing Record9 of Set 15 | paulo ramos
# Processing Record10 of Set 15 | hihifo
# City not found. Skipping....
# Processing Record11 of Set 15 | igrim
# Processing Record12 of Set 15 | dutse
# Processing Record13 of Set 15 | djibo
# Processing Record14 of Set 15 | diffa
# Processing Record15 of Set 15 | dukat
# Processing Record16 of Set 15 | raga
# Processing Record17 of Set 15 | acaponeta
# Processing Record18 of Set 15 | makakilo city
# Processing Record19 of Set 15 | sibenik
# Processing Record20 of Set 15 | crotone
# Processing Record21 of Set 15 | anzio
# Processing Record22 of Set 15 | salacgriva
# Processing Record23 of Set 15 | obo
# Processing Record24 of Set 15 | tupik
# Processing Record25 of Set 15 | nyazepetrovsk
# Processing Record26 of Set 15 | sakakah
# Processing Record27 of Set 15 | altay
# Processing Record28 of Set 15 | quesnel
# Processing Record29 of Set 15 | cheyenne
# Processing Record30 of Set 15 | port macquarie
# Processing Record31 of Set 15 | marrakesh
# Processing Record32 of Set 15 | sulangan
# Processing Record33 of Set 15 | reconquista
# Processing Record34 of Set 15 | chapais
# Processing Record35 of Set 15 | aksarka
# Processing Record36 of Set 15 | roros
# Processing Record37 of Set 15 | armacao dos buzios
# City not found. Skipping....
# Processing Record38 of Set 15 | bayan
# Processing Record39 of Set 15 | balasinor
# City not found. Skipping....
# Processing Record40 of Set 15 | armidale
# Processing Record41 of Set 15 | orda
# Processing Record42 of Set 15 | beaufort
# Processing Record43 of Set 15 | preobrazheniye
# Processing Record44 of Set 15 | zhuhai
# Processing Record45 of Set 15 | kapit
# Processing Record46 of Set 15 | menongue
# --------------------
# Data Load Complete
# ---Thanks for Waiting----

# %%
#Create Dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Albany      US  42.6001  -73.9662     64.63        82          92
# 1       Cape Town      ZA -33.9258   18.4232     64.11        84          97
# 2      Susanville      US  40.4163 -120.6530     70.81        27           1
# 3       Jamestown      US  42.0970  -79.2353     69.39        80          90
# 4      Butaritari      KI   3.0707  172.7902     81.39        68          40
# 5         Rikitea      PF -23.1203 -134.9692     74.68        81          98
# 6         Andenes      NO  69.3143   16.1194     46.08        81          75
# 7  Saint-Philippe      RE -21.3585   55.7679     72.95        88           7
# 8        Hoa Binh      VN  20.8133  105.3383     73.29        99         100
# 9     Yellowknife      CA  62.4560 -114.3525     37.42        99         100
#
#    Wind Speed       Description
# 0        4.36   overcast clouds
# 1        4.94   overcast clouds
# 2        1.01         clear sky
# 3        8.01   overcast clouds
# 4        9.48  scattered clouds
# 5       19.06   overcast clouds
# 6        4.61     broken clouds
# 7        6.46         clear sky
# 8        4.56   overcast clouds
# 9       15.99        light rain

# %%
#Output file 
output_data_file = "Weather_Database/WeatherPy_Database.csv"
#Export the city_data into a csv titled cities.csv
city_data_df.to_csv(output_data_file,index_label="City_ID")
